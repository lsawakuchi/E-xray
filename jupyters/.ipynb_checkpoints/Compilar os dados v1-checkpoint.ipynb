# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, make_scorer

# %%
def calculate_pearson(df):
    correlations = {}
    numerical_features = df.select_dtypes(exclude = ["object"]).columns
    numerical_features = numerical_features.drop("cod_municipio")
    for i in numerical_features:
        corr = stats.pearsonr(df[i], df['ideb'])[0]
        correlations[i] = corr
    df_corr = pd.DataFrame(list(correlations.items()), columns=['feature', 'correlation_with_ideb'])        
    df_corr = df_corr.dropna()
    
    return df_corr

# %%
def calculate_categorical_correlation(df):
    categorical_features = df.select_dtypes(include = ["object"]).columns
    return categorical_features

# %% [markdown]
# # Puxa dados do CSV de cada integrante do grupo

# %% [markdown]
# ### Dados Alexandre

# %%
path = '../dataset/'

# %%
#Dados iniciais
alexandre_inicio_2015 = pd.read_csv(path + 'bases_ale/anos_iniciais/ideb_municipios_2015_ai.csv')
alexandre_inicio_2017 = pd.read_csv(path + 'bases_ale/anos_iniciais/ideb_municipios_2017_ai.csv')

# Dados finais
alexandre_final_2015 = pd.read_csv(path + 'bases_ale/anos_finais/ideb_municipios_2015_af.csv')
alexandre_final_2017 = pd.read_csv(path + 'bases_ale/anos_finais/ideb_municipios_2017_af.csv')

# %% [markdown]
# ### Dados Lidia

# %%
#Dados iniciais
lidia_inicio_2007 = pd.read_csv(path + 'bases_lidia/anos_iniciais/ideb_escola_2007_ai.csv')
lidia_inicio_2009 = pd.read_csv(path + 'bases_lidia/anos_iniciais/ideb_escola_2009_ai.csv')
lidia_inicio_2011 = pd.read_csv(path + 'bases_lidia/anos_iniciais/ideb_escola_2011_ai.csv')
lidia_inicio_2013 = pd.read_csv(path + 'bases_lidia/anos_iniciais/ideb_escola_2013_ai.csv')
lidia_inicio_2015 = pd.read_csv(path + 'bases_lidia/anos_iniciais/ideb_escola_2015_ai.csv')
lidia_inicio_2017 = pd.read_csv(path + 'bases_lidia/anos_iniciais/ideb_escola_2017_ai.csv')

# Dados finais
lidia_final_2007 = pd.read_csv(path + 'bases_lidia/anos_finais/ideb_escola_2007_af.csv')
lidia_final_2009 = pd.read_csv(path + 'bases_lidia/anos_finais/ideb_escola_2009_af.csv')
lidia_final_2011 = pd.read_csv(path + 'bases_lidia/anos_finais/ideb_escola_2011_af.csv')
lidia_final_2013 = pd.read_csv(path + 'bases_lidia/anos_finais/ideb_escola_2013_af.csv')
lidia_final_2015 = pd.read_csv(path + 'bases_lidia/anos_finais/ideb_escola_2015_af.csv')
lidia_final_2017 = pd.read_csv(path + 'bases_lidia/anos_finais/ideb_escola_2017_af.csv')
# Out:
# /home/alexandre_silva/.virtualenvs/E-xray-0edG8woV/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (48,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/alexandre_silva/.virtualenvs/E-xray-0edG8woV/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (48,50,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/alexandre_silva/.virtualenvs/E-xray-0edG8woV/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (48,50,52,170) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/alexandre_silva/.virtualenvs/E-xray-0edG8woV/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (47,49,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/alexandre_silva/.virtualenvs/E-xray-0edG8woV/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (47,49,51,169) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Dados William

# %%
#Dados iniciais
william_inicio_2005 = pd.read_csv(path + 'bases_william/anos_iniciais/dados2005_inic.csv')
william_inicio_2007 = pd.read_csv(path + 'bases_william/anos_iniciais/dados2007_inic.csv')
william_inicio_2009 = pd.read_csv(path + 'bases_william/anos_iniciais/dados2009_inic.csv')
william_inicio_2011 = pd.read_csv(path + 'bases_william/anos_iniciais/dados2011_inic.csv')
william_inicio_2013 = pd.read_csv(path + 'bases_william/anos_iniciais/dados2013_inic.csv')
william_inicio_2015 = pd.read_csv(path + 'bases_william/anos_iniciais/dados2015_inic.csv')
william_inicio_2017 = pd.read_csv(path + 'bases_william/anos_iniciais/dados2017_inic.csv')


# Dados finais
william_final_2005 = pd.read_csv(path + 'bases_william/anos_finais/dados2005_fim.csv')
william_final_2007 = pd.read_csv(path + 'bases_william/anos_finais/dados2007_fim.csv')
william_final_2009 = pd.read_csv(path + 'bases_william/anos_finais/dados2009_fim.csv')
william_final_2011 = pd.read_csv(path + 'bases_william/anos_finais/dados2011_fim.csv')
william_final_2013 = pd.read_csv(path + 'bases_william/anos_finais/dados2013_fim.csv')
william_final_2015 = pd.read_csv(path + 'bases_william/anos_finais/dados2015_fim.csv')
william_final_2017 = pd.read_csv(path + 'bases_william/anos_finais/dados2017_fim.csv')

# %% [markdown]
# # Retirar dados NaN

# %% [markdown]
# ### Lidia

# %%
print(lidia_inicio_2007.shape)
print(lidia_inicio_2007.count()-lidia_inicio_2007.shape[0])

print(lidia_inicio_2009.shape)
print(lidia_inicio_2009.count()-lidia_inicio_2009.shape[0])

print(lidia_inicio_2011.shape)
print(lidia_inicio_2011.count()-lidia_inicio_2011.shape[0])

print(lidia_inicio_2013.shape)
print(lidia_inicio_2013.count()-lidia_inicio_2013.shape[0])

print(lidia_inicio_2015.shape)
print(lidia_inicio_2015.count()-lidia_inicio_2015.shape[0])

print(lidia_inicio_2017.shape)
print(lidia_inicio_2017.count()-lidia_inicio_2017.shape[0])

print(lidia_final_2007.shape)
print(lidia_final_2007.count()-lidia_final_2007.shape[0])

print(lidia_final_2009.shape)
print(lidia_final_2009.count()-lidia_final_2009.shape[0])

print(lidia_final_2011.shape)
print(lidia_final_2011.count()-lidia_final_2011.shape[0])

print(lidia_final_2013.shape)
print(lidia_final_2013.count()-lidia_final_2013.shape[0])

print(lidia_final_2015.shape)
print(lidia_final_2015.count()-lidia_final_2015.shape[0])

print(lidia_final_2017.shape)
print(lidia_final_2017.count()-lidia_final_2017.shape[0])
# Out:
# (41759, 204)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                               -80
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee               -80
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                                -80
# num_estudantes                                -80
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil                -80
# num_estudantes_ensino_fund_anos_iniciais      -80
# num_estudantes_ensino_fund_anos_finais        -80
# num_estudantes_ensino_medio_propedeutico      -80
# num_estudantes_fund_1_ano                     -80
# num_estudantes_fund_2_ano                     -80
# num_estudantes_fund_3_ano                     -80
#                                             ...
# ideb_2015_af_media_mat                     -13089
# ideb_2015_af_proficiencia                  -13089
# ideb_2015_af_fluxo                         -10128
# ideb_2015_anos_finais                      -13098
# tp_aee                                          0
# tp_aee_desc                                -41759
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -41759
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                   -80
# tp_localizacao_diferenciada_desc              -80
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                          -80
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -41759
# co_lingua_indigena                         -41648
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -41759
# num_estudantes_ensino_integral             -41759
# tp_integral                                -41759
# cod_ibge_uf                                     0
# ano                                        -13254
# ideb                                       -13254
# tp_rede                                    -13254
# uf                                         -13254
# Length: 204, dtype: int64
# (42369, 184)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -217
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -217
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -217
# num_estudantes                               -217
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -217
# num_estudantes_ensino_fund_anos_iniciais     -217
# num_estudantes_ensino_fund_anos_finais       -217
# num_estudantes_ensino_medio_propedeutico     -217
# num_estudantes_fund_1_ano                    -217
# num_estudantes_fund_2_ano                    -217
# num_estudantes_fund_3_ano                    -217
#                                             ...
# num_professores_em_regencia                  -222
# num_professores_em_regencia_fund_ai          -222
# num_professores_em_regencia_fund_af          -222
# num_professores_em_regencia_ens_medio        -222
# tp_aee                                          0
# tp_aee_desc                                -38716
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -33855
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -217
# tp_localizacao_diferenciada_desc             -217
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -217
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -42369
# co_lingua_indigena                         -42274
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -42369
# num_estudantes_ensino_integral             -42369
# tp_integral                                -42369
# cod_ibge_uf                                     0
# ano                                        -13459
# ideb                                       -13459
# tp_rede                                    -13459
# uf                                         -13459
# Length: 184, dtype: int64
# (42784, 184)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -359
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -359
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -359
# num_estudantes                               -359
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -359
# num_estudantes_ensino_fund_anos_iniciais     -359
# num_estudantes_ensino_fund_anos_finais       -359
# num_estudantes_ensino_medio_propedeutico     -359
# num_estudantes_fund_1_ano                    -359
# num_estudantes_fund_2_ano                    -359
# num_estudantes_fund_3_ano                    -359
#                                             ...
# num_professores_em_regencia                  -359
# num_professores_em_regencia_fund_ai          -359
# num_professores_em_regencia_fund_af          -359
# num_professores_em_regencia_ens_medio        -359
# tp_aee                                          0
# tp_aee_desc                                -34894
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -28723
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -359
# tp_localizacao_diferenciada_desc             -359
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -359
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -42784
# co_lingua_indigena                         -42682
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -27925
# num_estudantes_ensino_integral             -27925
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                        -13649
# ideb                                       -13649
# tp_rede                                    -13649
# uf                                         -13649
# Length: 184, dtype: int64
# (43163, 184)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -625
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -625
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -625
# num_estudantes                               -625
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -625
# num_estudantes_ensino_fund_anos_iniciais     -625
# num_estudantes_ensino_fund_anos_finais       -625
# num_estudantes_ensino_medio_propedeutico     -625
# num_estudantes_fund_1_ano                    -625
# num_estudantes_fund_2_ano                    -625
# num_estudantes_fund_3_ano                    -625
#                                             ...
# num_professores_em_regencia                  -625
# num_professores_em_regencia_fund_ai          -625
# num_professores_em_regencia_fund_af          -625
# num_professores_em_regencia_ens_medio        -625
# tp_aee                                          0
# tp_aee_desc                                -31844
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -20589
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -625
# tp_localizacao_diferenciada_desc             -625
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -625
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43163
# co_lingua_indigena                         -43060
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -22731
# num_estudantes_ensino_integral             -22731
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                        -13805
# ideb                                       -13805
# tp_rede                                    -13805
# uf                                         -13805
# Length: 184, dtype: int64
# (43378, 184)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -792
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -792
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -792
# num_estudantes                               -792
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -792
# num_estudantes_ensino_fund_anos_iniciais     -792
# num_estudantes_ensino_fund_anos_finais       -792
# num_estudantes_ensino_medio_propedeutico     -792
# num_estudantes_fund_1_ano                    -792
# num_estudantes_fund_2_ano                    -792
# num_estudantes_fund_3_ano                    -792
#                                             ...
# num_professores_em_regencia                  -792
# num_professores_em_regencia_fund_ai          -792
# num_professores_em_regencia_fund_af          -792
# num_professores_em_regencia_ens_medio        -792
# tp_aee                                          0
# tp_aee_desc                                -29093
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -18744
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -792
# tp_localizacao_diferenciada_desc             -792
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -792
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43189
# co_lingua_indigena                         -43270
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -18982
# num_estudantes_ensino_integral             -18982
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                        -13923
# ideb                                       -13923
# tp_rede                                    -13923
# uf                                         -13923
# Length: 184, dtype: int64
# (43586, 184)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                             -1040
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee             -1040
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                              -1040
# num_estudantes                              -1040
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil              -1040
# num_estudantes_ensino_fund_anos_iniciais    -1040
# num_estudantes_ensino_fund_anos_finais      -1040
# num_estudantes_ensino_medio_propedeutico    -1040
# num_estudantes_fund_1_ano                   -1040
# num_estudantes_fund_2_ano                   -1040
# num_estudantes_fund_3_ano                   -1040
#                                             ...
# num_professores_em_regencia                 -1040
# num_professores_em_regencia_fund_ai         -1040
# num_professores_em_regencia_fund_af         -1040
# num_professores_em_regencia_ens_medio       -1040
# tp_aee                                          0
# tp_aee_desc                                -27346
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -22067
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                 -1040
# tp_localizacao_diferenciada_desc            -1040
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                        -1040
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43404
# co_lingua_indigena                         -43461
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -23009
# num_estudantes_ensino_integral             -23009
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                        -14065
# ideb                                       -14065
# tp_rede                                    -14065
# uf                                         -14065
# Length: 184, dtype: int64
# (42784, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -359
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -359
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -359
# num_estudantes                               -359
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -359
# num_estudantes_ensino_fund_anos_iniciais     -359
# num_estudantes_ensino_fund_anos_finais       -359
# num_estudantes_ensino_medio_propedeutico     -359
# num_estudantes_fund_1_ano                    -359
# num_estudantes_fund_2_ano                    -359
# num_estudantes_fund_3_ano                    -359
# num_estudantes_fund_4_ano                    -359
#                                             ...
# num_professores_em_regencia                  -359
# num_professores_em_regencia_fund_ai          -359
# num_professores_em_regencia_fund_af          -359
# num_professores_em_regencia_ens_medio        -359
# tp_aee                                          0
# tp_aee_desc                                -34894
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -28723
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -359
# tp_localizacao_diferenciada_desc             -359
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -359
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -42784
# co_lingua_indigena                         -42682
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -27925
# num_estudantes_ensino_integral             -27925
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64
# (42369, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -217
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -217
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -217
# num_estudantes                               -217
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -217
# num_estudantes_ensino_fund_anos_iniciais     -217
# num_estudantes_ensino_fund_anos_finais       -217
# num_estudantes_ensino_medio_propedeutico     -217
# num_estudantes_fund_1_ano                    -217
# num_estudantes_fund_2_ano                    -217
# num_estudantes_fund_3_ano                    -217
# num_estudantes_fund_4_ano                    -217
#                                             ...
# num_professores_em_regencia                  -222
# num_professores_em_regencia_fund_ai          -222
# num_professores_em_regencia_fund_af          -222
# num_professores_em_regencia_ens_medio        -222
# tp_aee                                          0
# tp_aee_desc                                -38716
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -33855
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -217
# tp_localizacao_diferenciada_desc             -217
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -217
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -42369
# co_lingua_indigena                         -42274
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -42369
# num_estudantes_ensino_integral             -42369
# tp_integral                                -42369
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64
# (42784, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -359
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -359
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -359
# num_estudantes                               -359
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -359
# num_estudantes_ensino_fund_anos_iniciais     -359
# num_estudantes_ensino_fund_anos_finais       -359
# num_estudantes_ensino_medio_propedeutico     -359
# num_estudantes_fund_1_ano                    -359
# num_estudantes_fund_2_ano                    -359
# num_estudantes_fund_3_ano                    -359
# num_estudantes_fund_4_ano                    -359
#                                             ...
# num_professores_em_regencia                  -359
# num_professores_em_regencia_fund_ai          -359
# num_professores_em_regencia_fund_af          -359
# num_professores_em_regencia_ens_medio        -359
# tp_aee                                          0
# tp_aee_desc                                -34894
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -28723
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -359
# tp_localizacao_diferenciada_desc             -359
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -359
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -42784
# co_lingua_indigena                         -42682
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -27925
# num_estudantes_ensino_integral             -27925
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64
# (43163, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -625
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -625
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -625
# num_estudantes                               -625
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -625
# num_estudantes_ensino_fund_anos_iniciais     -625
# num_estudantes_ensino_fund_anos_finais       -625
# num_estudantes_ensino_medio_propedeutico     -625
# num_estudantes_fund_1_ano                    -625
# num_estudantes_fund_2_ano                    -625
# num_estudantes_fund_3_ano                    -625
# num_estudantes_fund_4_ano                    -625
#                                             ...
# num_professores_em_regencia                  -625
# num_professores_em_regencia_fund_ai          -625
# num_professores_em_regencia_fund_af          -625
# num_professores_em_regencia_ens_medio        -625
# tp_aee                                          0
# tp_aee_desc                                -31844
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -20589
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -625
# tp_localizacao_diferenciada_desc             -625
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -625
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43163
# co_lingua_indigena                         -43060
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -22731
# num_estudantes_ensino_integral             -22731
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64
# (43378, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -792
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -792
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -792
# num_estudantes                               -792
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -792
# num_estudantes_ensino_fund_anos_iniciais     -792
# num_estudantes_ensino_fund_anos_finais       -792
# num_estudantes_ensino_medio_propedeutico     -792
# num_estudantes_fund_1_ano                    -792
# num_estudantes_fund_2_ano                    -792
# num_estudantes_fund_3_ano                    -792
# num_estudantes_fund_4_ano                    -792
#                                             ...
# num_professores_em_regencia                  -792
# num_professores_em_regencia_fund_ai          -792
# num_professores_em_regencia_fund_af          -792
# num_professores_em_regencia_ens_medio        -792
# tp_aee                                          0
# tp_aee_desc                                -29093
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -18744
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -792
# tp_localizacao_diferenciada_desc             -792
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -792
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43189
# co_lingua_indigena                         -43270
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -18982
# num_estudantes_ensino_integral             -18982
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64
# (43586, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                             -1040
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee             -1040
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                              -1040
# num_estudantes                              -1040
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil              -1040
# num_estudantes_ensino_fund_anos_iniciais    -1040
# num_estudantes_ensino_fund_anos_finais      -1040
# num_estudantes_ensino_medio_propedeutico    -1040
# num_estudantes_fund_1_ano                   -1040
# num_estudantes_fund_2_ano                   -1040
# num_estudantes_fund_3_ano                   -1040
# num_estudantes_fund_4_ano                   -1040
#                                             ...
# num_professores_em_regencia                 -1040
# num_professores_em_regencia_fund_ai         -1040
# num_professores_em_regencia_fund_af         -1040
# num_professores_em_regencia_ens_medio       -1040
# tp_aee                                          0
# tp_aee_desc                                -27346
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -22067
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                 -1040
# tp_localizacao_diferenciada_desc            -1040
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                        -1040
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43404
# co_lingua_indigena                         -43461
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -23009
# num_estudantes_ensino_integral             -23009
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64

# %%
print('antes', lidia_inicio_2007.shape)
lidia_inicio_2007 = lidia_inicio_2007.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_inicio_2007.shape)
lidia_inicio_2007 = lidia_inicio_2007.dropna()
print('dados limpo',lidia_inicio_2007.shape)

print('antes',lidia_inicio_2009.shape)
lidia_inicio_2009 = lidia_inicio_2009.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_inicio_2009.shape)
lidia_inicio_2009 = lidia_inicio_2009.dropna()
print('dados limpo',lidia_inicio_2009.shape)

print('antes',lidia_inicio_2011.shape)
lidia_inicio_2011 = lidia_inicio_2011.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_inicio_2011.shape)
lidia_inicio_2011 = lidia_inicio_2011.dropna()
print('dados limpo',lidia_inicio_2011.shape)

print('antes',lidia_inicio_2013.shape)
lidia_inicio_2013 = lidia_inicio_2013.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_inicio_2013.shape)
lidia_inicio_2013 = lidia_inicio_2013.dropna()
print('dados limpo',lidia_inicio_2013.shape)

print('antes',lidia_inicio_2015.shape)
lidia_inicio_2015 = lidia_inicio_2015.dropna(axis='columns',thresh=15000)
print(lidia_inicio_2015.shape)
lidia_inicio_2015 = lidia_inicio_2015.dropna()
print('dados limpo',lidia_inicio_2015.shape)

print('antes',lidia_inicio_2017.shape)
lidia_inicio_2017 = lidia_inicio_2017.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_inicio_2017.shape)
lidia_inicio_2017 = lidia_inicio_2017.dropna()
print('dados limpo',lidia_inicio_2017.shape)

print('antes', lidia_final_2007.shape)
lidia_final_2007 = lidia_final_2007.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_final_2007.shape)
lidia_final_2007 = lidia_final_2007.dropna()
print('dados limpo',lidia_final_2007.shape)

print('antes',lidia_final_2009.shape)
lidia_final_2009 = lidia_final_2009.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_final_2009.shape)
lidia_final_2009 = lidia_final_2009.dropna()
print('dados limpo',lidia_final_2009.shape)

print('antes',lidia_final_2011.shape)
lidia_final_2011 = lidia_final_2011.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_final_2011.shape)
lidia_final_2011 = lidia_final_2011.dropna()
print('dados limpo',lidia_final_2011.shape)

print('antes',lidia_final_2013.shape)
lidia_final_2013 = lidia_final_2013.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_final_2013.shape)
lidia_final_2013 = lidia_final_2013.dropna()
print('dados limpo',lidia_final_2013.shape)

print('antes',lidia_final_2015.shape)
lidia_final_2015 = lidia_final_2015.dropna(axis='columns',thresh=15000)
print(lidia_final_2015.shape)
lidia_final_2015 = lidia_final_2015.dropna()
print('dados limpo',lidia_final_2015.shape)

print('antes',lidia_final_2017.shape)
lidia_final_2017 = lidia_final_2017.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_final_2017.shape)
lidia_final_2017 = lidia_final_2017.dropna()
print('dados limpo',lidia_final_2017.shape)
# Out:
# antes (41759, 204)
# sem algumas colunas (41759, 189)
# dados limpo (9664, 189)
# antes (42369, 184)
# sem algumas colunas (42369, 169)
# dados limpo (28640, 169)
# antes (42784, 184)
# sem algumas colunas (42784, 170)
# dados limpo (27429, 170)
# antes (43163, 184)
# sem algumas colunas (43163, 174)
# dados limpo (11947, 174)
# antes (43378, 184)
# (43378, 173)
# dados limpo (14653, 173)
# antes (43586, 184)
# sem algumas colunas (43586, 174)
# dados limpo (5777, 174)
# antes (42784, 183)
# sem algumas colunas (42784, 169)
# dados limpo (40063, 169)
# antes (42369, 183)
# sem algumas colunas (42369, 168)
# dados limpo (41852, 168)
# antes (42784, 183)
# sem algumas colunas (42784, 169)
# dados limpo (40063, 169)
# antes (43163, 183)
# sem algumas colunas (43163, 173)
# dados limpo (15652, 173)
# antes (43378, 183)
# (43378, 172)
# dados limpo (19065, 172)
# antes (43586, 183)
# sem algumas colunas (43586, 173)
# dados limpo (6948, 173)

# %% [markdown]
# ### Alexandre

# %%
print(alexandre_inicio_2015.shape)
print(alexandre_inicio_2015.count()-alexandre_inicio_2015.shape[0])

print(alexandre_inicio_2017.shape)
print(alexandre_inicio_2017.count()-alexandre_inicio_2017.shape[0])

print(alexandre_final_2015.shape)
print(alexandre_final_2015.count()-alexandre_final_2015.shape[0])

print(alexandre_final_2017.shape)
print(alexandre_final_2017.count()-alexandre_final_2017.shape[0])
# Out:
# (12048, 47)
# Unnamed: 0                                  0
# ano_censo                                   0
# regiao                                      0
# unidade_federativa                          0
# mesoregiao                                  0
# microregiao                                 0
# municipio                                   0
# cod_municipio                               0
# num_escolas                                 0
# num_escolas_em_atividade                    0
# num_estudantes_ensino_infantil              0
# num_estudantes_ensino_fund_anos_iniciais    0
# num_estudantes_ensino_fund_anos_finais      0
# num_estudantes_fund_1_ano                   0
# num_estudantes_fund_2_ano                   0
# num_estudantes_fund_3_ano                   0
# num_estudantes_fund_4_ano                   0
# num_estudantes_fund_5_ano                   0
# num_estudantes_fund_6_ano                   0
# num_estudantes_fund_7_ano                   0
# num_estudantes_fund_8_ano                   0
# num_estudantes_fund_9_ano                   0
# num_salas_existentes                        0
# num_salas_utilizadas                        0
# num_equip_tv                                0
# num_equip_videocassete                      0
# num_equip_dvd                               0
# num_equip_parabolica                        0
# num_equip_copiadora                         0
# num_equip_retroprojetor                     0
# num_equip_impressora                        0
# num_equip_impressora_mult                   0
# num_equip_som                               0
# num_equip_multimidia                        0
# num_equip_fax                               0
# num_equip_foto                              0
# num_computador                              0
# num_comp_administrativo                     0
# num_comp_aluno                              0
# num_funcionarios                            0
# num_escolas_rurais                          0
# num_escolas_urbanas                         0
# num_professores                             0
# num_matriculas                              0
# num_estudantes                              0
# num_turmas                                  0
# ideb                                        0
# dtype: int64
# (12508, 47)
# Unnamed: 0                                  0
# ano_censo                                   0
# regiao                                      0
# unidade_federativa                          0
# mesoregiao                                  0
# microregiao                                 0
# municipio                                   0
# cod_municipio                               0
# num_escolas                                 0
# num_escolas_em_atividade                    0
# num_estudantes_ensino_infantil              0
# num_estudantes_ensino_fund_anos_iniciais    0
# num_estudantes_ensino_fund_anos_finais      0
# num_estudantes_fund_1_ano                   0
# num_estudantes_fund_2_ano                   0
# num_estudantes_fund_3_ano                   0
# num_estudantes_fund_4_ano                   0
# num_estudantes_fund_5_ano                   0
# num_estudantes_fund_6_ano                   0
# num_estudantes_fund_7_ano                   0
# num_estudantes_fund_8_ano                   0
# num_estudantes_fund_9_ano                   0
# num_salas_existentes                        0
# num_salas_utilizadas                        0
# num_equip_tv                                0
# num_equip_videocassete                      0
# num_equip_dvd                               0
# num_equip_parabolica                        0
# num_equip_copiadora                         0
# num_equip_retroprojetor                     0
# num_equip_impressora                        0
# num_equip_impressora_mult                   0
# num_equip_som                               0
# num_equip_multimidia                        0
# num_equip_fax                               0
# num_equip_foto                              0
# num_computador                              0
# num_comp_administrativo                     0
# num_comp_aluno                              0
# num_funcionarios                            0
# num_escolas_rurais                          0
# num_escolas_urbanas                         0
# num_professores                             0
# num_matriculas                              0
# num_estudantes                              0
# num_turmas                                  0
# ideb                                        0
# dtype: int64
# (12158, 41)
# Unnamed: 0                                  0
# ano_censo                                   0
# regiao                                      0
# unidade_federativa                          0
# mesoregiao                                  0
# microregiao                                 0
# municipio                                   0
# cod_municipio                               0
# num_escolas                                 0
# num_escolas_em_atividade                    0
# num_estudantes_ensino_medio_propedeutico    0
# num_estudantes_medio_1_serie                0
# num_estudantes_medio_2_serie                0
# num_estudantes_medio_3_serie                0
# num_estudantes_medio_4_serie                0
# num_estudantes_medio_nao_seriada            0
# num_salas_existentes                        0
# num_salas_utilizadas                        0
# num_equip_tv                                0
# num_equip_videocassete                      0
# num_equip_dvd                               0
# num_equip_parabolica                        0
# num_equip_copiadora                         0
# num_equip_retroprojetor                     0
# num_equip_impressora                        0
# num_equip_impressora_mult                   0
# num_equip_som                               0
# num_equip_multimidia                        0
# num_equip_fax                               0
# num_equip_foto                              0
# num_computador                              0
# num_comp_administrativo                     0
# num_comp_aluno                              0
# num_funcionarios                            0
# num_escolas_rurais                          0
# num_escolas_urbanas                         0
# num_professores                             0
# num_matriculas                              0
# num_estudantes                              0
# num_turmas                                  0
# ideb                                        0
# dtype: int64
# (12751, 41)
# Unnamed: 0                                  0
# ano_censo                                   0
# regiao                                      0
# unidade_federativa                          0
# mesoregiao                                  0
# microregiao                                 0
# municipio                                   0
# cod_municipio                               0
# num_escolas                                 0
# num_escolas_em_atividade                    0
# num_estudantes_ensino_medio_propedeutico    0
# num_estudantes_medio_1_serie                0
# num_estudantes_medio_2_serie                0
# num_estudantes_medio_3_serie                0
# num_estudantes_medio_4_serie                0
# num_estudantes_medio_nao_seriada            0
# num_salas_existentes                        0
# num_salas_utilizadas                        0
# num_equip_tv                                0
# num_equip_videocassete                      0
# num_equip_dvd                               0
# num_equip_parabolica                        0
# num_equip_copiadora                         0
# num_equip_retroprojetor                     0
# num_equip_impressora                        0
# num_equip_impressora_mult                   0
# num_equip_som                               0
# num_equip_multimidia                        0
# num_equip_fax                               0
# num_equip_foto                              0
# num_computador                              0
# num_comp_administrativo                     0
# num_comp_aluno                              0
# num_funcionarios                            0
# num_escolas_rurais                          0
# num_escolas_urbanas                         0
# num_professores                             0
# num_matriculas                              0
# num_estudantes                              0
# num_turmas                                  0
# ideb                                        0
# dtype: int64

# %% [markdown]
# ### William

# %%
print(william_inicio_2007.shape)
print(william_inicio_2007.count()-william_inicio_2007.shape[0])

print(william_inicio_2009.shape)
print(william_inicio_2009.count()-william_inicio_2009.shape[0])

print(william_inicio_2011.shape)
print(william_inicio_2011.count()-william_inicio_2011.shape[0])

print(william_inicio_2013.shape)
print(william_inicio_2013.count()-william_inicio_2013.shape[0])

print(william_inicio_2015.shape)
print(william_inicio_2015.count()-william_inicio_2015.shape[0])

print(william_inicio_2017.shape)
print(william_inicio_2017.count()-william_inicio_2017.shape[0])

print(william_final_2007.shape)
print(william_final_2007.count()-william_final_2007.shape[0])

print(william_final_2009.shape)
print(william_final_2009.count()-william_final_2009.shape[0])

print(william_final_2011.shape)
print(william_final_2011.count()-william_final_2011.shape[0])

print(william_final_2013.shape)
print(william_final_2013.count()-william_final_2013.shape[0])

print(william_final_2015.shape)
print(william_final_2015.count()-william_final_2015.shape[0])

print(william_final_2017.shape)
print(william_final_2017.count()-william_final_2017.shape[0])
# Out:
# (128, 15)
# Unnamed: 0                           0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (120, 16)
# Unnamed: 0                           0
# index                                0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (128, 15)
# Unnamed: 0                           0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (128, 15)
# Unnamed: 0                           0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (128, 15)
# Unnamed: 0                           0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (127, 16)
# Unnamed: 0                           0
# index                                0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (128, 14)
# Unnamed: 0                          0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64
# (121, 15)
# Unnamed: 0                          0
# index                               0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64
# (128, 14)
# Unnamed: 0                          0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64
# (128, 14)
# Unnamed: 0                          0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64
# (128, 14)
# Unnamed: 0                          0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64
# (128, 14)
# Unnamed: 0                          0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64

# %% [markdown]
# # Correlação

# %% [markdown]
# ### Lidia

# %%
lidia_corr__inicio_2007 = calculate_pearson(lidia_inicio_2007)
lidia_corr__inicio_2007 = lidia_corr__inicio_2007.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__inicio_2009 = calculate_pearson(lidia_inicio_2009)
lidia_corr__inicio_2009 = lidia_corr__inicio_2009.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__inicio_2011 = calculate_pearson(lidia_inicio_2011)
lidia_corr__inicio_2011 = lidia_corr__inicio_2011.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__inicio_2013 = calculate_pearson(lidia_inicio_2013)
lidia_corr__inicio_2013 = lidia_corr__inicio_2013.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__inicio_2015 = calculate_pearson(lidia_inicio_2015)
lidia_corr__inicio_2015 = lidia_corr__inicio_2015.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__inicio_2017 = calculate_pearson(lidia_inicio_2017)
lidia_corr__inicio_2017 = lidia_corr__inicio_2017.sort_values(by=['correlation_with_ideb'], ascending=False)

lidia_corr__final_2007 = calculate_pearson(lidia_final_2007)
lidia_corr__final_2007 = lidia_corr__final_2007.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__final_2009 = calculate_pearson(lidia_final_2009)
lidia_corr__final_2009 = lidia_corr__final_2009.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__final_2011 = calculate_pearson(lidia_final_2011)
lidia_corr__final_2011 = lidia_corr__final_2011.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__final_2013 = calculate_pearson(lidia_final_2013)
lidia_corr__final_2013 = lidia_corr__final_2013.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__final_2015 = calculate_pearson(lidia_final_2015)
lidia_corr__final_2015 = lidia_corr__final_2015.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__final_2017 = calculate_pearson(lidia_final_2017)
lidia_corr__final_2017 = lidia_corr__final_2017.sort_values(by=['correlation_with_ideb'], ascending=False)
# Out:
# /home/alexandre_silva/.virtualenvs/E-xray-0edG8woV/lib/python3.5/site-packages/scipy/stats/stats.py:3010: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
print(lidia_corr__inicio_2007)
print(lidia_corr__inicio_2009)
print(lidia_corr__inicio_2011)
print(lidia_corr__inicio_2013)
print(lidia_corr__inicio_2015)
print(lidia_corr__inicio_2017)
# Out:
#                             feature  correlation_with_ideb
# 45                             ideb               1.000000
# 56                     Unnamed: 0.1               0.537197
# 149                      Unnamed: 0               0.537197
# 60          ideb_2013_anos_iniciais               0.528504
# 95          ideb_2013_ai_media_port               0.524285
# 4         ideb_2013_ai_proficiencia               0.519969
# 65           ideb_2013_ai_media_mat               0.505612
# 126         ideb_2015_ai_media_port               0.483675
# 59          ideb_2015_anos_iniciais               0.472666
# 102       ideb_2015_ai_proficiencia               0.471025
# 78           ideb_2015_ai_media_mat               0.443483
# 61        ideb_2013_af_proficiencia               0.420138
# 82          ideb_2013_af_media_port               0.414646
# 160       ideb_2015_af_proficiencia               0.411284
# 118          ideb_2013_af_media_mat               0.407111
# 21           ideb_2015_af_media_mat               0.402166
# 83            ideb_2013_anos_finais               0.396607
# 79          ideb_2015_af_media_port               0.396309
# 71            ideb_2015_anos_finais               0.366991
# 89                      in_internet               0.353571
# 117          in_esgoto_rede_publica               0.349012
# 68               ideb_2013_ai_fluxo               0.345682
# 94                  cod_escola_inep               0.340136
# 18                      cod_ibge_uf               0.339936
# 11         in_lixo_coleta_periodica               0.333688
# 32             in_agua_rede_publica               0.330027
# 76               ideb_2015_ai_fluxo               0.316351
# 162          in_equip_retroprojetor               0.296575
# 81               in_equip_copiadora               0.287850
# 129              in_quadra_esportes               0.267280
# ..                              ...                    ...
# 172                      in_cozinha               0.017329
# 52           in_dependencias_outras               0.005189
# 119       num_estudantes_fund_6_ano               0.004145
# 23      in_local_func_salas_empresa              -0.004249
# 13     in_local_func_unid_prisional              -0.009235
# 38      in_local_func_templo_igreja              -0.010202
# 152    num_estudantes_medio_4_serie              -0.016149
# 110          in_energia_inexistente              -0.023504
# 36              in_agua_inexistente              -0.033491
# 8      in_local_func_casa_professor              -0.039466
# 105   in_local_func_salas_outra_esc              -0.041796
# 98             in_educacao_indigena              -0.049447
# 154                 in_lixo_enterra              -0.053564
# 166              in_energia_gerador              -0.059180
# 150               in_energia_outros              -0.061225
# 169         in_predio_compartilhado              -0.063514
# 170           in_esgoto_inexistente              -0.065991
# 107  num_estudantes_ensino_infantil              -0.079739
# 115                in_agua_filtrada              -0.088172
# 164              tp_ocupacao_galpao              -0.090553
# 134            in_local_func_outros              -0.094738
# 84                in_agua_fonte_rio              -0.100079
# 165         in_lixo_joga_outra_area              -0.141284
# 130     tp_localizacao_diferenciada              -0.147959
# 93                  in_agua_cacimba              -0.186996
# 168          in_agua_poco_artesiano              -0.216736
# 114                  tp_dependencia              -0.245464
# 53                   in_lixo_queima              -0.302359
# 171                 in_esgoto_fossa              -0.327050
# 125                  tp_localizacao              -0.730676
#
# [110 rows x 2 columns]
#                                       feature  correlation_with_ideb
# 120                                      ideb               1.000000
# 25        num_professores_em_regencia_fund_ai               0.487514
# 19                  num_estudantes_fund_5_ano               0.452148
# 138  num_estudantes_ensino_fund_anos_iniciais               0.426481
# 65                  num_estudantes_fund_4_ano               0.369853
# 93                  num_estudantes_fund_3_ano               0.351902
# 74                       num_salas_existentes               0.341334
# 8                                 in_internet               0.339687
# 22                   in_lixo_coleta_periodica               0.334990
# 27                  num_estudantes_fund_2_ano               0.334964
# 18                            num_professores               0.334780
# 125               num_professores_em_regencia               0.333911
# 82                                 num_turmas               0.320369
# 68                       num_salas_utilizadas               0.311338
# 83                           num_funcionarios               0.305220
# 129                 num_estudantes_fund_1_ano               0.304434
# 119                            in_banda_larga               0.298161
# 64                     in_esgoto_rede_publica               0.291567
# 85                         in_quadra_esportes               0.291155
# 102                            num_matriculas               0.281248
# 29                        in_equip_impressora               0.279888
# 33                          in_sala_professor               0.279303
# 116                            num_estudantes               0.277290
# 94                         in_equip_copiadora               0.274553
# 56                     in_equip_retroprojetor               0.274280
# 20                            cod_escola_inep               0.269599
# 36                                cod_ibge_uf               0.269225
# 75                              in_computador               0.260622
# 57                       in_agua_rede_publica               0.258704
# 149                in_laboratorio_informatica               0.238747
# ..                                        ...                    ...
# 42                in_local_func_salas_empresa              -0.000206
# 143                            in_lixo_outros              -0.006106
# 67                        in_agua_inexistente              -0.006585
# 137           in_somente_matriculas_ac_ou_aee              -0.014495
# 69                in_local_func_templo_igreja              -0.019021
# 109                in_material_esp_quilombola              -0.022917
# 122                    in_dependencias_outras              -0.025173
# 124                   in_predio_compartilhado              -0.033512
# 28                    in_banheiro_fora_predio              -0.034150
# 16               in_local_func_casa_professor              -0.037044
# 152                      in_local_func_outros              -0.043590
# 118                         in_energia_outros              -0.049252
# 147                     in_esgoto_inexistente              -0.059868
# 34                         tp_ocupacao_galpao              -0.062852
# 10                   in_material_esp_indigena              -0.066050
# 128                           in_lixo_enterra              -0.066730
# 13                       in_educacao_indigena              -0.088574
# 49                     in_energia_inexistente              -0.091704
# 145                        in_energia_gerador              -0.094226
# 115                         in_agua_fonte_rio              -0.109103
# 46                tp_localizacao_diferenciada              -0.109236
# 60                             tp_dependencia              -0.114244
# 144                   in_lixo_joga_outra_area              -0.114461
# 95                            in_agua_cacimba              -0.145839
# 151                    in_agua_poco_artesiano              -0.147765
# 148                           in_esgoto_fossa              -0.274690
# 105                            in_lixo_queima              -0.294661
# 12                             tp_localizacao              -0.353150
# 117                                Unnamed: 0              -0.445186
# 111                              Unnamed: 0.1              -0.445186
#
# [100 rows x 2 columns]
#                                       feature  correlation_with_ideb
# 120                                      ideb               1.000000
# 25        num_professores_em_regencia_fund_ai               0.521066
# 19                  num_estudantes_fund_5_ano               0.501985
# 139  num_estudantes_ensino_fund_anos_iniciais               0.481464
# 65                  num_estudantes_fund_4_ano               0.454035
# 27                  num_estudantes_fund_2_ano               0.401783
# 93                  num_estudantes_fund_3_ano               0.390021
# 129                 num_estudantes_fund_1_ano               0.375847
# 82                                 num_turmas               0.281500
# 68                       num_salas_utilizadas               0.260978
# 125               num_professores_em_regencia               0.256260
# 18                            num_professores               0.252930
# 83                           num_funcionarios               0.251840
# 102                            num_matriculas               0.237217
# 116                            num_estudantes               0.235074
# 64                     in_esgoto_rede_publica               0.230482
# 22                   in_lixo_coleta_periodica               0.219332
# 74                       num_salas_existentes               0.215001
# 8                                 in_internet               0.200869
# 11                      in_fundamental_ciclos               0.196938
# 119                            in_banda_larga               0.191240
# 45                 in_quadra_esportes_coberta               0.188384
# 94                         in_equip_copiadora               0.178230
# 57                       in_agua_rede_publica               0.176558
# 56                     in_equip_retroprojetor               0.167621
# 33                          in_sala_professor               0.164504
# 40                  tp_atividade_complementar               0.160674
# 72                                     tp_aee               0.159717
# 20                            cod_escola_inep               0.157453
# 36                                cod_ibge_uf               0.156968
# ..                                        ...                    ...
# 138           in_somente_matriculas_ac_ou_aee              -0.013221
# 118                         in_energia_outros              -0.014167
# 6            num_estudantes_medio_nao_seriada              -0.014662
# 97                        in_equip_parabolica              -0.019437
# 144                            in_lixo_outros              -0.020971
# 34                         tp_ocupacao_galpao              -0.021484
# 10                   in_material_esp_indigena              -0.022288
# 16               in_local_func_casa_professor              -0.025117
# 109                in_material_esp_quilombola              -0.025432
# 124                   in_predio_compartilhado              -0.029020
# 148                     in_esgoto_inexistente              -0.031463
# 13                       in_educacao_indigena              -0.035457
# 106     num_professores_em_regencia_ens_medio              -0.035815
# 143              num_estudantes_medio_1_serie              -0.041672
# 146                        in_energia_gerador              -0.042749
# 113              num_estudantes_medio_2_serie              -0.044678
# 92   num_estudantes_ensino_medio_propedeutico              -0.045593
# 96               num_estudantes_medio_3_serie              -0.052573
# 67                        in_agua_inexistente              -0.054342
# 115                         in_agua_fonte_rio              -0.062035
# 128                           in_lixo_enterra              -0.063120
# 145                   in_lixo_joga_outra_area              -0.074852
# 46                tp_localizacao_diferenciada              -0.082004
# 95                            in_agua_cacimba              -0.100325
# 152                    in_agua_poco_artesiano              -0.107742
# 105                            in_lixo_queima              -0.190972
# 149                           in_esgoto_fossa              -0.221417
# 12                             tp_localizacao              -0.248462
# 111                              Unnamed: 0.1              -0.334343
# 117                                Unnamed: 0              -0.334343
#
# [102 rows x 2 columns]
#                                       feature  correlation_with_ideb
# 122                                      ideb               1.000000
# 20                  num_estudantes_fund_5_ano               0.531190
# 26        num_professores_em_regencia_fund_ai               0.487543
# 142  num_estudantes_ensino_fund_anos_iniciais               0.475902
# 66                  num_estudantes_fund_4_ano               0.448017
# 95                  num_estudantes_fund_3_ano               0.400929
# 28                  num_estudantes_fund_2_ano               0.396181
# 132                 num_estudantes_fund_1_ano               0.392300
# 75                       num_salas_existentes               0.237512
# 69                       num_salas_utilizadas               0.217967
# 23                   in_lixo_coleta_periodica               0.216075
# 145                        in_parque_infantil               0.206288
# 84                                 num_turmas               0.190511
# 73                                     tp_aee               0.183314
# 85                           num_funcionarios               0.179057
# 21                            cod_escola_inep               0.174370
# 37                                cod_ibge_uf               0.174006
# 19                            num_professores               0.173707
# 81               in_sala_atendimento_especial               0.173052
# 128               num_professores_em_regencia               0.172858
# 44                              num_equip_som               0.172618
# 9                                 in_internet               0.166472
# 46                 in_quadra_esportes_coberta               0.162927
# 158                      num_equip_impressora               0.160269
# 121                            in_banda_larga               0.158749
# 65                     in_esgoto_rede_publica               0.157674
# 58                       in_agua_rede_publica               0.157366
# 118                            num_estudantes               0.154707
# 34                          in_sala_professor               0.153498
# 80                             in_banheiro_ei               0.146086
# ..                                        ...                    ...
# 99                        in_equip_parabolica              -0.014619
# 50                     in_energia_inexistente              -0.016690
# 127                   in_predio_compartilhado              -0.017164
# 149                        in_energia_gerador              -0.021294
# 111                in_material_esp_quilombola              -0.021864
# 14                       in_educacao_indigena              -0.022636
# 120                         in_energia_outros              -0.022934
# 11                   in_material_esp_indigena              -0.024202
# 35                         tp_ocupacao_galpao              -0.025185
# 72                  num_estudantes_fund_8_ano              -0.025328
# 6                             in_sala_leitura              -0.026501
# 103                       in_alojam_professor              -0.028963
# 7            num_estudantes_medio_nao_seriada              -0.036699
# 15                  num_estudantes_fund_9_ano              -0.040172
# 151                     in_esgoto_inexistente              -0.041291
# 117                         in_agua_fonte_rio              -0.053079
# 131                           in_lixo_enterra              -0.054713
# 68                        in_agua_inexistente              -0.061933
# 47                tp_localizacao_diferenciada              -0.071345
# 97                            in_agua_cacimba              -0.079048
# 148                   in_lixo_joga_outra_area              -0.080926
# 155                    in_agua_poco_artesiano              -0.081757
# 146              num_estudantes_medio_1_serie              -0.098270
# 115              num_estudantes_medio_2_serie              -0.101921
# 94   num_estudantes_ensino_medio_propedeutico              -0.106599
# 108     num_professores_em_regencia_ens_medio              -0.110662
# 98               num_estudantes_medio_3_serie              -0.111384
# 152                           in_esgoto_fossa              -0.141228
# 107                            in_lixo_queima              -0.186703
# 13                             tp_localizacao              -0.228842
#
# [134 rows x 2 columns]
#                                       feature  correlation_with_ideb
# 121                                      ideb               1.000000
# 26        num_professores_em_regencia_fund_ai               0.572594
# 20                  num_estudantes_fund_5_ano               0.566457
# 141  num_estudantes_ensino_fund_anos_iniciais               0.560409
# 4                            in_comum_fund_ai               0.550724
# 65                  num_estudantes_fund_4_ano               0.526113
# 94                  num_estudantes_fund_3_ano               0.499464
# 28                  num_estudantes_fund_2_ano               0.499401
# 131                 num_estudantes_fund_1_ano               0.479569
# 83                                 num_turmas               0.329714
# 74                       num_salas_existentes               0.294192
# 68                       num_salas_utilizadas               0.286437
# 103                            num_matriculas               0.284327
# 19                            num_professores               0.280975
# 127               num_professores_em_regencia               0.275764
# 117                            num_estudantes               0.273753
# 84                           num_funcionarios               0.269667
# 23                   in_lixo_coleta_periodica               0.257608
# 45                 in_quadra_esportes_coberta               0.240256
# 89                    num_comp_administrativo               0.235977
# 144                        in_parque_infantil               0.223951
# 86                         in_quadra_esportes               0.222498
# 72                                     tp_aee               0.219928
# 21                            cod_escola_inep               0.215542
# 36                                cod_ibge_uf               0.215107
# 80               in_sala_atendimento_especial               0.212958
# 137                            num_computador               0.211561
# 43                              num_equip_som               0.208246
# 64                     in_esgoto_rede_publica               0.207423
# 57                       in_agua_rede_publica               0.184377
# ..                                        ...                    ...
# 119                         in_energia_outros              -0.024294
# 156                           in_alojam_aluno              -0.028837
# 66                       in_local_func_galpao              -0.033805
# 126                   in_predio_compartilhado              -0.035220
# 152                        tp_indigena_lingua              -0.037077
# 14                       in_educacao_indigena              -0.037585
# 149                      num_equip_parabolica              -0.044012
# 98                        in_equip_parabolica              -0.044530
# 104                              in_comum_pre              -0.044925
# 148                        in_energia_gerador              -0.048582
# 150                     in_esgoto_inexistente              -0.052612
# 50                           in_comum_fund_af              -0.053153
# 102                       in_alojam_professor              -0.056175
# 130                           in_lixo_enterra              -0.058481
# 2                             in_comum_creche              -0.068860
# 96                            in_agua_cacimba              -0.070321
# 116                         in_agua_fonte_rio              -0.070719
# 67                        in_agua_inexistente              -0.076809
# 147                   in_lixo_joga_outra_area              -0.085721
# 114              num_estudantes_medio_2_serie              -0.089459
# 145              num_estudantes_medio_1_serie              -0.091618
# 97               num_estudantes_medio_3_serie              -0.092971
# 93   num_estudantes_ensino_medio_propedeutico              -0.093006
# 46                tp_localizacao_diferenciada              -0.097479
# 154                    in_agua_poco_artesiano              -0.106080
# 107     num_professores_em_regencia_ens_medio              -0.107445
# 25                       in_comum_medio_medio              -0.136577
# 151                           in_esgoto_fossa              -0.190499
# 106                            in_lixo_queima              -0.242870
# 13                             tp_localizacao              -0.265421
#
# [148 rows x 2 columns]
#                                       feature  correlation_with_ideb
# 121                                      ideb               1.000000
# 4                            in_comum_fund_ai               0.623850
# 118                                Unnamed: 0               0.511451
# 112                              Unnamed: 0.1               0.511451
# 26        num_professores_em_regencia_fund_ai               0.378488
# 20                  num_estudantes_fund_5_ano               0.339761
# 141  num_estudantes_ensino_fund_anos_iniciais               0.334839
# 65                  num_estudantes_fund_4_ano               0.331921
# 28                  num_estudantes_fund_2_ano               0.304710
# 131                 num_estudantes_fund_1_ano               0.294467
# 94                  num_estudantes_fund_3_ano               0.283709
# 144                        in_parque_infantil               0.171117
# 60                             tp_dependencia               0.157467
# 43                              num_equip_som               0.123444
# 89                    num_comp_administrativo               0.121716
# 45                 in_quadra_esportes_coberta               0.121699
# 104                              in_comum_pre               0.117842
# 2                             in_comum_creche               0.117165
# 44             num_estudantes_ensino_infantil               0.116986
# 48                              in_lavanderia               0.115512
# 79                             in_banheiro_ei               0.100814
# 76                            in_lixo_recicla               0.095151
# 86                         in_quadra_esportes               0.093665
# 21                            cod_escola_inep               0.093564
# 36                                cod_ibge_uf               0.093361
# 100                             in_refeitorio               0.089151
# 47                               in_equip_som               0.086015
# 68                       num_salas_utilizadas               0.082800
# 51                             num_comp_aluno               0.077951
# 137                            num_computador               0.076889
# ..                                        ...                    ...
# 106                            in_lixo_queima              -0.024097
# 102                       in_alojam_professor              -0.025603
# 6                             in_sala_leitura              -0.026457
# 33                    in_formacao_alternancia              -0.027236
# 154                    in_agua_poco_artesiano              -0.029626
# 85                            in_final_semana              -0.034666
# 46                tp_localizacao_diferenciada              -0.036434
# 27               in_local_func_unid_prisional              -0.039845
# 142                tp_ocupacao_predio_escolar              -0.040570
# 124            num_estudantes_ensino_integral              -0.040975
# 82             num_matriculas_ensino_integral              -0.040979
# 8               in_local_func_prisional_socio              -0.041547
# 32                      in_comum_medio_normal              -0.044262
# 129                  in_comum_medio_integrado              -0.046167
# 50                           in_comum_fund_af              -0.046977
# 151                           in_esgoto_fossa              -0.054326
# 14                       in_educacao_indigena              -0.055040
# 152                        tp_indigena_lingua              -0.057275
# 145              num_estudantes_medio_1_serie              -0.117559
# 107     num_professores_em_regencia_ens_medio              -0.118089
# 114              num_estudantes_medio_2_serie              -0.123732
# 97               num_estudantes_medio_3_serie              -0.124683
# 93   num_estudantes_ensino_medio_propedeutico              -0.125793
# 25                       in_comum_medio_medio              -0.127456
# 37        num_professores_em_regencia_fund_af              -0.139396
# 71                  num_estudantes_fund_8_ano              -0.143706
# 15                  num_estudantes_fund_9_ano              -0.144691
# 70                  num_estudantes_fund_6_ano              -0.156313
# 88                  num_estudantes_fund_7_ano              -0.160073
# 109    num_estudantes_ensino_fund_anos_finais              -0.163365
#
# [145 rows x 2 columns]

# %% [markdown]
# print(lidia_corr__final_2007)
# print(lidia_corr__final_2009)
# print(lidia_corr__final_2011)
# print(lidia_corr__final_2013)
# print(lidia_corr__final_2015)
# print(lidia_corr__final_2017)

# %% [markdown]
# ### Variaveis categoricas

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[0]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[3]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[7]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[8]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[9]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[10]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[11]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[12]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[6]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
print('Before getting dummys',lidia_inicio_2007.shape)
lidia_inicio_2007 = pd.get_dummies(lidia_inicio_2007)
print('after getting dummys',lidia_inicio_2007.shape)
# Out:
# Before getting dummys (9664, 189)
# after getting dummys (9664, 16038)

# %%
y = lidia_inicio_2007['ideb']
x = lidia_inicio_2007.drop(columns=['ideb'])

# %%
# Partition the dataset in train + validation sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3,random_state=1)

# %%
# Define error measure for official scoring : RMSE
scorer = make_scorer(mean_squared_error, greater_is_better = False)

def rmse_cv_train(model):
    rmse= np.sqrt(-cross_val_score(model, X_train, y_train, scoring = scorer, cv = 5))
    return(rmse)

def rmse_cv_test(model):
    rmse= np.sqrt(-cross_val_score(model, X_test, y_test, scoring = scorer, cv = 5))
    return(rmse)

# %% [markdown]
# # Ridge Regression

# %%
ridge = RidgeCV(alphas = [0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6, 10, 30, 60])
ridge.fit(X_train, y_train)
alpha = ridge.alpha_
print("Best alpha :", alpha)

# %%
print("Try again for more precision with alphas centered around " + str(alpha))
ridge = RidgeCV(alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, alpha * .85, 
                          alpha * .9, alpha * .95, alpha, alpha * 1.05, alpha * 1.1, alpha * 1.15,
                          alpha * 1.25, alpha * 1.3, alpha * 1.35, alpha * 1.4], 
                cv = 10)
ridge.fit(X_train, y_train)
alphaRidge = ridge.alpha_
print("Best alpha :", alphaRidge)

# %%
ridge = make_pipeline(StandardScaler(), Ridge(alpha = alphaRidge, random_state=1))
ridge.fit(X_train, y_train)

# %%
print("Ridge RMSE on Training set :", rmse_cv_train(ridge).mean())
print("Ridge RMSE on Training error :", rmse_cv_train(ridge).std())
print("Ridge RMSE on Test set :", rmse_cv_test(ridge).mean())
print("Ridge RMSE on Test error :", rmse_cv_test(ridge).std())
y_train_rdg = ridge.predict(X_train)
y_test_rdg = ridge.predict(X_test)

# %%
# Plot residuals
plt.scatter(y_train_rdg, y_train_rdg - y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_rdg, y_test_rdg - y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression with Ridge regularization")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.legend(loc = "upper left")
plt.hlines(y = 0, xmin = 10.5, xmax = 13.5, color = "red")
plt.show()

# %%
# Plot important coefficients
coefs = pd.Series(ridge.coef_, index = X_train.columns)
print("Ridge picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh")
plt.title("Coefficients in the Ridge Model")
plt.show()
